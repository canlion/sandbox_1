# %%
import torch

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from torchvision import transforms, models

# %%
model = models.densenet161(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /root/.cache/torch/checkpoints/densenet161-8d451a50.pth
# ...

# %%
for i, l in enumerate(model.children()[0]):
    print(i, l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c73feb6cce81> in <module>
# ----> 1 for i, l in enumerate(model.children()[0]):
#       2     print(i, l)
#
# TypeError: 'generator' object is not subscriptable

# %%
for i, item in enumerate(model.features._modules.items()):
    print(i+1, item)

# %%
model.features._modules['transition1'][-1]
# Out:
# AvgPool2d(kernel_size=2, stride=2, padding=0)

# %%
model.features._modules.keys()
# Out:
# odict_keys(['conv0', 'norm0', 'relu0', 'pool0', 'denseblock1', 'transition1', 'denseblock2', 'transition2', 'denseblock3', 'transition3', 'denseblock4', 'norm5'])

# %%
for i, (k, v) in enumerate(model.features._modules.items()):
    print(i+1, k, v)
# Out:
# 1 conv0 Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# 2 norm0 BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 3 relu0 ReLU(inplace=True)
# 4 pool0 MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# 5 denseblock1 _DenseBlock(
#   (denselayer1): _DenseLayer(
#     (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
#     (conv1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace=True)
#     (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (denselayer2): _DenseLayer(
#     (norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace=True)
# ...
